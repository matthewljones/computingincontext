# %%
import urllib
import json
sunlight_api="70a35a7e121e4984a217bb84ab07e85a"
phrase_to_search="cyber+security"    
my_api_call="http://capitolwords.org/api/1/text.json?phrase="+phrase_to_search+"&apikey="+sunlight_api
doc_str = urllib.urlopen(my_api_call).read()
response_dict=json.loads(doc_str)
responses=response_dict['results']

# %%
len(responses)
# Out:
# 50

# %%
responses[9]
# Out:
# {u'bills': None,
#  u'bioguide_id': u'C001067',
#  u'capitolwords_url': u'http://capitolwords.org/date/2009/10/01/E2429_sixth-annual-national-cyber-security-awareness-mon/',
#  u'chamber': u'Extensions',
#  u'congress': 111,
#  u'date': u'2009-10-01',
#  u'id': u'CREC-2009-10-01-pt1-PgE2429.chunk0',
#  u'number': 140,
#  u'order': 0,
#  u'origin_url': u'http://origin.www.gpo.gov/fdsys/pkg/CREC-2009-10-01/html/CREC-2009-10-01-pt1-PgE2429.htm',
#  u'pages': u'E2429',
#  u'session': 1,
#  u'speaker_first': u'Yvette',
#  u'speaker_last': u'Clarke',
#  u'speaker_party': u'D',
#  u'speaker_raw': u'ms. clarke',
#  u'speaker_state': u'NY',
#  u'speaking': [u'Madam Speaker, I rise in support of the sixth annual National Cybersecurity Awareness Month, which kicks off today.',
# ...

# %%
[" ".join(response["speaking"]) for response in responses]
# Out:
# [u'Lighthouse Cyber-Security...........................................5',
#  u' Lighthouse cyber-security.....................................3.8',
#  u'Mitigation Programs.......................................197,111,000Subtotal, Infrastructure Protection.........................347,303,000National Cyber Security Division:',
#  u'Cyber Security Research...................................... 5.0Defense-wide Research, Development, Test and Evaluation:',
#  u' for urban and rural water systems.Cyber Security......................................................128Food safety, securing biohazardous materials at USDA facilities, ',
#  u'Outreach and Programs.......................................9,346,000Subtotal, National Cyber Security Division..................397,154,000Office of Emergency Communications...........................45,060,000National Security/Emergency Preparedness (NS/EP) Telecommunications:',
# ...

# %%
" ".join(["how", "now", "brown", "cow"])
# Out:
# 'how now brown cow'
